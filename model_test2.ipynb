# %% [markdown]
# ## Linear Regression Using Statsmodels

# %%
# Alternative Method Using Statsmodels

import statsmodels.api as sm

Y = df['price']
X = df.drop('price', axis=1)
Xcont = sm.add_constant(X)

np.asarray(Y)
np.asarray(Xcont)

model = sm.OLS(Y, Xcont)
fitted_model = model.fit()
fitted_model.summary()



#_____From Lecture

# y = advertising.Sales

# independent_variables = ['TV', 'Radio']
# X = advertising[independent_variables]

# add constant to make the y-intercept on y=mx+b
# without constant it will pass through 0,0 instead of y-int.

# import statsmodels.api as sm

# Xcont = sm.add_constant(X)

# model = sm.OLS(y, Xcont)
# fitted_model = model.fit()
# fitted_model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-802d6236459e> in <module>
#      10 np.asarray(Xcont)
#      11
# ---> 12 model = sm.OLS(Y, Xcont)
#      13 fitted_model = model.fit()
#      14 fitted_model.summary()
#
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     857                  **kwargs):
#     858         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 859                                   hasconst=hasconst, **kwargs)
#     860         if "weights" in self._init_keys:
#     861             self._init_keys.remove("weights")
#
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     700             weights = weights.squeeze()
# ...

# %%
import statsmodels.api as sm

Y = df['price']
X = df.drop('price', axis=1)

X.head(3)
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1  6414100192  12/9/2014         3       2.25         2570      7242     2.0
# 2  5631500400  2/25/2015         2       1.00          770     10000     1.0
# 3  2487200875  12/9/2014         4       3.00         1960      5000     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 1         0.0   0.0          3      7        2170            400      1951
# 2         0.0   0.0          3      6         770              0      1933
# 3         0.0   0.0          5      7        1050            910      1965
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 1        1991.0    98125  47.7210 -122.319           1690        7639
# 2           NaN    98028  47.7379 -122.233           2720        8062
# 3           0.0    98136  47.5208 -122.393           1360        5000
