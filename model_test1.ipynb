# %% [markdown]
# ## Create Model

# %% [markdown]
# ### Model Using df_data

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
dependent_var = 'price'
predictors = df_data.drop('price', axis=1)
predictors_sum = '+'.join(predictors.columns)
formula = dependent_var + '~' + predictors_sum

model = ols(formula=formula, data=df_data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     2264.
# Date:                Wed, 08 Jul 2020   Prob (F-statistic):               0.00
# Time:                        08:02:35   Log-Likelihood:            -2.1230e+05
# No. Observations:               15474   AIC:                         4.246e+05
# Df Residuals:                   15460   BIC:                         4.247e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Model Using train_set

# %%
dependent_var = 'price'
predictors = train_set.drop('price', axis=1)
predictors_sum = '+'.join(predictors.columns)
formula = dependent_var + '~' + predictors_sum

model = ols(formula=formula, data=train_set).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     1843.
# Date:                Wed, 08 Jul 2020   Prob (F-statistic):               0.00
# Time:                        08:03:08   Log-Likelihood:            -1.6998e+05
# No. Observations:               12394   AIC:                         3.400e+05
# Df Residuals:                   12380   BIC:                         3.401e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Plotting the Model

# %%
from sklearn.linear_model import LinearRegression

x = train_set.iloc[:, 0].values.reshape(-1, 1)
y = train_set.iloc[:, 1].values.reshape(-1, 1)

linear_regressor = LinearRegression()

linear_regressor.fit(predictors_sum, )

plt.scatter(train_set, train_set['price'], color = 'red')
plt.plot(train_set, model, color = 'blue')
plt.title('Housing Features Vs. Price (Training Set)')
plt.ylabel('House Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-c7f22086d83d> in <module>
# ----> 1 plt.scatter(train_set, train_set['price'], color = 'red')
#       2 plt.plot(train_set, model, color = 'blue')
#       3 plt.title('Housing Features Vs. Price (Training Set)')
#       4 plt.ylabel('House Price')
#       5 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# DID NOT WORK
plt.scatter(train_set, train_set['price'], color = 'red')
plt.plot(train_set, model, color = 'blue')
plt.title('Housing Features Vs. Price (Training Set)')
plt.ylabel('House Price')
plt.show()
